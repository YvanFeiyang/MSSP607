# %% [markdown]
# # Week3 - Theoretical Questions and the Collatz Sequence
# - Theoretical Questions
# - The Collatz Sequence

# %% [markdown]
# ## I. Theoretical Questions

# %% [markdown]
# ### a.When does the code in a function execute: when the function is defined or called?
#
# The code in a function executes when the function is called, not when it is defined.

# %% [markdown]
# ### b. How many global scopes are there in a Python program? How many local scopes?
#
# There is only one global scope in a Python program.
# There are many local scopes, because each time a function is called, Python will create a new local scope for that call.

# %% [markdown]
# ### c. What happens to variables in a local scope when the function call returns?
#
# When a function call returns, the variables in its local scope are destroyed and no longer accessible.

# %% [markdown]
# ### d. How can you prevent a program from crashing when it gets an error?
# We can use exception handling with try and except blocks to prevent it from crashing.

# %% [markdown]
# ## II. The Collatz Sequence

# %% [markdown]
# Rule
# - If number is even, return number // 2
# - If number is odd, return 3 * number + 1
# - Repeat until number = 1

# %%
def collatz(number):
    if number % 2 == 0:
        result = number // 2
    else:
        result = 3 * number + 1
    return result
    print(result)

# %%
while True:
    try:
        n = int(input("Enter a positive integer please: "))
        if n <= 0:
            print("Please enter an integer greater than 0")
            continue
        break
    except ValueError:
        print("Please enter an integer.")

print("Collatz sequence:")
while n != 1:
    print(n)
    n = collatz(n)
print(1)
# Out:
# Enter a positive integer please: 34
# Collatz sequence:
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1
